# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
# %matplotlib inline
import seaborn as sns
import quandl
from matplotlib.widgets import Slider

# %%
from datetime import datetime

# %%
quandl.ApiConfig.api_key = '4Zb6_91RYVTap7hzR7Y6'

# %%
stock_list = ['AAPL','MSFT','AMZN','GOOG']

# %%
df1 = quandl.get_table('WIKI/PRICES', ticker = stock_list, paginate = True)
df1
# Out:
#       ticker       date    open     high     low  close      volume  \
# None
# 0       AAPL 1980-12-12  28.750  28.8700  28.750  28.75   2093900.0
# 1       AAPL 1980-12-15  27.380  27.3800  27.250  27.25    785200.0
# 2       AAPL 1980-12-16  25.370  25.3700  25.250  25.25    472000.0
# 3       AAPL 1980-12-17  25.870  26.0000  25.870  25.87    385900.0
# 4       AAPL 1980-12-18  26.630  26.7500  26.630  26.63    327900.0
# 5       AAPL 1980-12-19  28.250  28.3800  28.250  28.25    217100.0
# 6       AAPL 1980-12-22  29.630  29.7500  29.630  29.63    166800.0
# 7       AAPL 1980-12-23  30.880  31.0000  30.880  30.88    209600.0
# 8       AAPL 1980-12-24  32.500  32.6300  32.500  32.50    214300.0
# 9       AAPL 1980-12-26  35.500  35.6200  35.500  35.50    248100.0
# 10      AAPL 1980-12-29  36.000  36.1300  36.000  36.00    415900.0
# 11      AAPL 1980-12-30  35.250  35.2500  35.120  35.12    307500.0
# 12      AAPL 1980-12-31  34.250  34.2500  34.130  34.13    159600.0
# ...

# %%
#Printing last 1 year data
start = datetime(2017, 1, 1)
#end = datetime.now()
end = datetime(2018, 12, 12)

# %%
file = quandl.get_table('WIKI/PRICES', ticker = stock_list, date = {'gte':start,'lte':end}, paginate=True).set_index("date")
file
# Out:
#            ticker     open      high       low   close       volume  \
# date
# 2017-01-03   AAPL  115.800  116.3300  114.7600  116.15   28781865.0
# 2017-01-04   AAPL  115.850  116.5100  115.7500  116.02   21118116.0
# 2017-01-05   AAPL  115.920  116.8642  115.8100  116.61   22193587.0
# 2017-01-06   AAPL  116.780  118.1600  116.4700  117.91   31751900.0
# 2017-01-09   AAPL  117.950  119.4300  117.9400  118.99   33561948.0
# 2017-01-10   AAPL  118.770  119.3800  118.3000  119.11   24462051.0
# 2017-01-11   AAPL  118.740  119.9300  118.6000  119.75   27588593.0
# 2017-01-12   AAPL  118.895  119.3000  118.2100  119.25   27086220.0
# 2017-01-13   AAPL  119.110  119.6200  118.8100  119.04   26111948.0
# 2017-01-17   AAPL  118.340  120.2400  118.2200  120.00   34439843.0
# 2017-01-18   AAPL  120.000  120.5000  119.7100  119.99   23712961.0
# 2017-01-19   AAPL  119.400  120.0900  119.3700  119.78   25597291.0
# 2017-01-20   AAPL  120.450  120.4500  119.7346  120.00   32597892.0
# ...

# %%
#Viewing values of Apple's stock
q1 = df1[df1.ticker == 'AAPL']
q1
# Out:
#      ticker       date     open     high       low    close      volume  \
# None
# 0      AAPL 1980-12-12   28.750   28.870   28.7500   28.750   2093900.0
# 1      AAPL 1980-12-15   27.380   27.380   27.2500   27.250    785200.0
# 2      AAPL 1980-12-16   25.370   25.370   25.2500   25.250    472000.0
# 3      AAPL 1980-12-17   25.870   26.000   25.8700   25.870    385900.0
# 4      AAPL 1980-12-18   26.630   26.750   26.6300   26.630    327900.0
# 5      AAPL 1980-12-19   28.250   28.380   28.2500   28.250    217100.0
# 6      AAPL 1980-12-22   29.630   29.750   29.6300   29.630    166800.0
# 7      AAPL 1980-12-23   30.880   31.000   30.8800   30.880    209600.0
# 8      AAPL 1980-12-24   32.500   32.630   32.5000   32.500    214300.0
# 9      AAPL 1980-12-26   35.500   35.620   35.5000   35.500    248100.0
# 10     AAPL 1980-12-29   36.000   36.130   36.0000   36.000    415900.0
# 11     AAPL 1980-12-30   35.250   35.250   35.1200   35.120    307500.0
# ...

# %%
#Displaying plot of closing price
q2 = df1[df1['ticker']=='AMZN']
q3 = df1[df1['ticker']=='GOOG']
q4 = df1[df1['ticker']=='MSFT']

# %%
plt.rcParams['figure.figsize']=(15.0,8.0)
style.use('ggplot')
plt.subplots_adjust(hspace = .25)
plt.subplot(2,2,1)
plt.title('Apple Closing Price Analysis')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.plot(q1.date,q1.close,color='red')
plt.legend(q1.ticker)
plt.subplot(2,2,2)
plt.title('Amazon Closing Price Analysis')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.plot(q2.date,q2.close,color='b')
plt.legend(q2.ticker)
plt.subplot(2,2,3)
plt.title('Google Closing Price Analysis')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.plot(q3.date,q3.close,color='g')
plt.legend(q3.ticker)
plt.subplot(2,2,4)
plt.title('Microsoft Closing Price Analysis')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.plot(q4.date,q4.close,color='c')
plt.legend(q4.ticker)
plt.show()

# %%
#Displaying stock trade by volume
plt.rcParams['figure.figsize']=(15.0,30.0)
style.use('ggplot')
plt.subplots_adjust(top=.9,bottom = .123)
plt.subplot(4,1,1)
plt.title('Apple Stock Volume Analysis')
q1['volume'].plot(legend=True,color='red')
plt.subplot(4,1,2)
plt.title('Amazon Stock Volume Analysis')
q2['volume'].plot(legend=True,color='b')
plt.subplot(4,1,3)
plt.title('Google Stock Volume Analysis')
q3['volume'].plot(legend=True,color='g')
plt.subplot(4,1,4)
plt.title('Microsoft Stock Volume Analysis')
q4['volume'].plot(legend=True,color='c')
plt.show()

# %%
#Plotting all companies data together for closing price
plt.rcParams['figure.figsize']=(50.0,15.0)
style.use('ggplot')
plt.subplots_adjust(hspace = .25)
plt.title('Apple Closing Price Analysis')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.subplot(2,2,1)
plt.plot(q1.date,q1.close,color='red')
plt.plot(q2.date,q2.close,color='b')
plt.plot(q3.date,q3.close,color='g')
plt.plot(q4.date,q4.close,color='c')
plt.legend(df1.ticker.unique())
plt.show()

# %%
#Plotting percentage change for Apple's stock
df1['percentage_change'] = df1['close'].pct_change()*100
df1
# Out:
#       ticker       date    open     high     low  close      volume  \
# None
# 0       AAPL 1980-12-12  28.750  28.8700  28.750  28.75   2093900.0
# 1       AAPL 1980-12-15  27.380  27.3800  27.250  27.25    785200.0
# 2       AAPL 1980-12-16  25.370  25.3700  25.250  25.25    472000.0
# 3       AAPL 1980-12-17  25.870  26.0000  25.870  25.87    385900.0
# 4       AAPL 1980-12-18  26.630  26.7500  26.630  26.63    327900.0
# 5       AAPL 1980-12-19  28.250  28.3800  28.250  28.25    217100.0
# 6       AAPL 1980-12-22  29.630  29.7500  29.630  29.63    166800.0
# 7       AAPL 1980-12-23  30.880  31.0000  30.880  30.88    209600.0
# 8       AAPL 1980-12-24  32.500  32.6300  32.500  32.50    214300.0
# 9       AAPL 1980-12-26  35.500  35.6200  35.500  35.50    248100.0
# 10      AAPL 1980-12-29  36.000  36.1300  36.000  36.00    415900.0
# 11      AAPL 1980-12-30  35.250  35.2500  35.120  35.12    307500.0
# 12      AAPL 1980-12-31  34.250  34.2500  34.130  34.13    159600.0
# ...

# %%
dt = df1[df1.percentage_change > 1.0]
dt
# Out:
#       ticker       date    open     high      low  close      volume  \
# None
# 3       AAPL 1980-12-17  25.870  26.0000  25.8700  25.87    385900.0
# 4       AAPL 1980-12-18  26.630  26.7500  26.6300  26.63    327900.0
# 5       AAPL 1980-12-19  28.250  28.3800  28.2500  28.25    217100.0
# 6       AAPL 1980-12-22  29.630  29.7500  29.6300  29.63    166800.0
# 7       AAPL 1980-12-23  30.880  31.0000  30.8800  30.88    209600.0
# 8       AAPL 1980-12-24  32.500  32.6300  32.5000  32.50    214300.0
# 9       AAPL 1980-12-26  35.500  35.6200  35.5000  35.50    248100.0
# 10      AAPL 1980-12-29  36.000  36.1300  36.0000  36.00    415900.0
# 13      AAPL 1981-01-02  34.500  34.7500  34.5000  34.50     96700.0
# 18      AAPL 1981-01-09  31.880  32.0000  31.8800  31.88     96000.0
# 22      AAPL 1981-01-15  31.250  31.5000  31.2500  31.25     62800.0
# 24      AAPL 1981-01-19  32.870  33.0000  32.8700  32.87    185600.0
# ...

# %%
#Percentage change for Apple's stock
pc = dt[dt['ticker']=='AAPL']

# %%
plt.rcParams['figure.figsize']=(35.0,15.0)
style.use('ggplot')
plt.title('Apple\'s Percentage Change')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.plot(pc.date,pc.percentage_change,color='g')
plt.show()

# %%
#plotting daily return change
df1['daily_return'] = df1['adj_close'].pct_change()
df1
# Out:
#       ticker       date    open     high     low  close      volume  \
# None
# 0       AAPL 1980-12-12  28.750  28.8700  28.750  28.75   2093900.0
# 1       AAPL 1980-12-15  27.380  27.3800  27.250  27.25    785200.0
# 2       AAPL 1980-12-16  25.370  25.3700  25.250  25.25    472000.0
# 3       AAPL 1980-12-17  25.870  26.0000  25.870  25.87    385900.0
# 4       AAPL 1980-12-18  26.630  26.7500  26.630  26.63    327900.0
# 5       AAPL 1980-12-19  28.250  28.3800  28.250  28.25    217100.0
# 6       AAPL 1980-12-22  29.630  29.7500  29.630  29.63    166800.0
# 7       AAPL 1980-12-23  30.880  31.0000  30.880  30.88    209600.0
# 8       AAPL 1980-12-24  32.500  32.6300  32.500  32.50    214300.0
# 9       AAPL 1980-12-26  35.500  35.6200  35.500  35.50    248100.0
# 10      AAPL 1980-12-29  36.000  36.1300  36.000  36.00    415900.0
# 11      AAPL 1980-12-30  35.250  35.2500  35.120  35.12    307500.0
# 12      AAPL 1980-12-31  34.250  34.2500  34.130  34.13    159600.0
# ...

# %%
df1['daily_return'].plot(figsize=(50,25),legend=True,linestyle='-',marker='H')

# %%
#Display jointplot between Apple and Google daily_return
ap = df1[df1.ticker == 'AAPL']
gog = df1[df1.ticker == 'GOOG']
ap
# Out:
#      ticker       date     open     high       low    close      volume  \
# None
# 0      AAPL 1980-12-12   28.750   28.870   28.7500   28.750   2093900.0
# 1      AAPL 1980-12-15   27.380   27.380   27.2500   27.250    785200.0
# 2      AAPL 1980-12-16   25.370   25.370   25.2500   25.250    472000.0
# 3      AAPL 1980-12-17   25.870   26.000   25.8700   25.870    385900.0
# 4      AAPL 1980-12-18   26.630   26.750   26.6300   26.630    327900.0
# 5      AAPL 1980-12-19   28.250   28.380   28.2500   28.250    217100.0
# 6      AAPL 1980-12-22   29.630   29.750   29.6300   29.630    166800.0
# 7      AAPL 1980-12-23   30.880   31.000   30.8800   30.880    209600.0
# 8      AAPL 1980-12-24   32.500   32.630   32.5000   32.500    214300.0
# 9      AAPL 1980-12-26   35.500   35.620   35.5000   35.500    248100.0
# 10     AAPL 1980-12-29   36.000   36.130   36.0000   36.000    415900.0
# 11     AAPL 1980-12-30   35.250   35.250   35.1200   35.120    307500.0
# ...

# %%
ap.rename(columns={'daily_return':'AAPL'})
# Out:
#      ticker       date     open     high       low    close      volume  \
# None
# 0      AAPL 1980-12-12   28.750   28.870   28.7500   28.750   2093900.0
# 1      AAPL 1980-12-15   27.380   27.380   27.2500   27.250    785200.0
# 2      AAPL 1980-12-16   25.370   25.370   25.2500   25.250    472000.0
# 3      AAPL 1980-12-17   25.870   26.000   25.8700   25.870    385900.0
# 4      AAPL 1980-12-18   26.630   26.750   26.6300   26.630    327900.0
# 5      AAPL 1980-12-19   28.250   28.380   28.2500   28.250    217100.0
# 6      AAPL 1980-12-22   29.630   29.750   29.6300   29.630    166800.0
# 7      AAPL 1980-12-23   30.880   31.000   30.8800   30.880    209600.0
# 8      AAPL 1980-12-24   32.500   32.630   32.5000   32.500    214300.0
# 9      AAPL 1980-12-26   35.500   35.620   35.5000   35.500    248100.0
# 10     AAPL 1980-12-29   36.000   36.130   36.0000   36.000    415900.0
# 11     AAPL 1980-12-30   35.250   35.250   35.1200   35.120    307500.0
# ...

# %%
gog.rename(columns={'daily_return':'GOOG'})
# Out:
#       ticker       date      open       high        low    close     volume  \
# None
# 14648   GOOG 2014-03-27   568.000   568.0000   552.9200   558.46    13100.0
# 14649   GOOG 2014-03-28   561.200   566.4300   558.6700   559.99    41100.0
# 14650   GOOG 2014-03-31   566.890   567.0000   556.9300   556.97    10800.0
# 14651   GOOG 2014-04-01   558.710   568.4500   558.7100   567.16     7900.0
# 14652   GOOG 2014-04-02   565.106   604.8300   562.1900   567.00   146700.0
# 14653   GOOG 2014-04-03   569.850   587.2800   564.1300   569.74  5085200.0
# 14654   GOOG 2014-04-04   574.650   577.7700   543.0000   543.14  6351900.0
# 14655   GOOG 2014-04-07   540.740   548.4800   527.1500   538.15  4389600.0
# 14656   GOOG 2014-04-08   542.600   555.0000   541.6100   554.90  3142600.0
# 14657   GOOG 2014-04-09   559.620   565.3700   552.9500   564.14  3321700.0
# 14658   GOOG 2014-04-10   565.000   565.0000   539.9000   540.95  4025800.0
# ...

# %%
#del ap['volume']
ap.rename(columns={'daily_return':'AAPL'})
# Out:
#      ticker       date  percentage_change      AAPL
# None
# 0      AAPL 1980-12-12                NaN       NaN
# 1      AAPL 1980-12-15          -5.217391 -0.052174
# 2      AAPL 1980-12-16          -7.339450 -0.073394
# 3      AAPL 1980-12-17           2.455446  0.024554
# 4      AAPL 1980-12-18           2.937766  0.029378
# 5      AAPL 1980-12-19           6.083365  0.060834
# 6      AAPL 1980-12-22           4.884956  0.048850
# 7      AAPL 1980-12-23           4.218697  0.042187
# 8      AAPL 1980-12-24           5.246114  0.052461
# 9      AAPL 1980-12-26           9.230769  0.092308
# 10     AAPL 1980-12-29           1.408451  0.014085
# 11     AAPL 1980-12-30          -2.444444 -0.024444
# 12     AAPL 1980-12-31          -2.818907 -0.028189
# 13     AAPL 1981-01-02           1.084090  0.010841
# 14     AAPL 1981-01-05          -2.173913 -0.021739
# 15     AAPL 1981-01-06          -4.444444 -0.044444
# 16     AAPL 1981-01-07          -4.248062 -0.042481
# ...

# %%
gog
# Out:
#       ticker       date  percentage_change  daily_return
# None
# 14648   GOOG 2014-03-27         -62.695969     -0.626960
# 14649   GOOG 2014-03-28           0.273968      0.002740
# 14650   GOOG 2014-03-31          -0.539295     -0.005393
# 14651   GOOG 2014-04-01           1.829542      0.018295
# 14652   GOOG 2014-04-02          -0.028211     -0.000282
# 14653   GOOG 2014-04-03           0.483245      0.004832
# 14654   GOOG 2014-04-04          -4.668796     -0.046688
# 14655   GOOG 2014-04-07          -0.918732     -0.009187
# 14656   GOOG 2014-04-08           3.112515      0.031125
# 14657   GOOG 2014-04-09           1.665165      0.016652
# 14658   GOOG 2014-04-10          -4.110682     -0.041107
# 14659   GOOG 2014-04-11          -1.913301     -0.019133
# 14660   GOOG 2014-04-14           0.361855      0.003619
# 14661   GOOG 2014-04-15           0.736123      0.007361
# 14662   GOOG 2014-04-16           3.746924      0.037469
# ...

# %%
######################################################

# %%
#Pairplot to show correlation between all the stocks

# %%
s1 = pd.merge(ap,gog,how='inner',on=['daily_return'])
s1
# Out:
# Empty DataFrame
# Columns: [ticker_x, date_x, open_x, high_x, low_x, close_x, volume_x, ex-dividend_x, split_ratio_x, adj_open_x, adj_high_x, adj_low_x, adj_close_x, adj_volume_x, percentage_change_x, daily_return, ticker_y, date_y, open_y, high_y, low_y, close_y, volume_y, ex-dividend_y, split_ratio_y, adj_open_y, adj_high_y, adj_low_y, adj_close_y, adj_volume_y, percentage_change_y]
# Index: []
#
# [0 rows x 31 columns]
